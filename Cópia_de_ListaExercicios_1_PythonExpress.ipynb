# %% [markdown]
# <a href="https://colab.research.google.com/github/lucas12339/Introducao-a-ciencia-de-dados/blob/main/C%C3%B3pia_de_ListaExercicios_1_PythonExpress.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***
# ## **<center>Lista de Exercícios 1 - Python Express</center>**
#
#
# **<center>Introdução a Ciência de Dados</center>**
# ***
#
# <br>
#
# Segue uma lista de exercícios abordando o conteúdo inicial para a programação em Python.
#
# Cada exercício deve ser respondido em uma célula específica.
#
#
# 1) Elabore um código que imprima a mensagem *"Olá terráqueos!!"* na tela.
#
#
# 2) Elabore um código que peça um número e então mostre a mensagem: *"O número informado foi [número]."*
#
#
# 3) Elabore um código que peça dois números e imprima a soma.
#
#
# 4) Elabore um código que peça as 4 notas bimestrais e mostre a média.
#
# 5) Elabore um código que converta metros para centímetros.
#
#
# 6) Elabore um código que peça o raio de um círculo, calcule e mostre sua área.
#
# 7) Elabore um código que calcule a área de um quadrado, em seguida mostre o dobro desta área para o usuário.
#
#
# 8) Elabore um código que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês em uma mensagem amigável.
#
#
# 9) Elabore um código que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# ** Onde C = 5 * ((F-32) / 9)**.
#
#
# 10) Elabore um código que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
#
#
# 11) Elabore um código que peça 2 números inteiros e um número real. Calcule e mostre:
# * o produto do dobro do primeiro com metade do segundo .
# * a soma do triplo do primeiro com o terceiro.
# * o terceiro elevado ao cubo.
#
# 12) Elabore um código que receba os dados de entrada a altura de uma pessoa, e informe qual seria o peso ideal, usando a seguinte fórmula: (72.7*altura) - 58

# %%
# 1) Elabore um código que imprima a mensagem *"Olá terráqueos!!"* na tela.

print("Olá terráqueos")
# Out:
# Olá terráqueos

# %%
numero0 = input( " digite um numero")
print( "numero escolhido foi", numero0)
# Out:
#  digite um numero9
# numero escolhido foi 9

# %%
n1 = input("digite um numero")
n2 = input("digite outro numero")
soma = ( int(n1)+ (int(n2)))
print ( "a soma é", soma)
# Out:
# digite um numero2
# digite outro numero3
# a soma é 5

# %%
n1 = input ("digite a primeira nota")
n2 =input ( "digite a segunda nota")
n3 = input("digite a terceira nota")
n4 =input("digite a quarta nota")
# Out:
# digite a primeira nota1
# digite a segunda nota2
# digite a terceira nota3
# digite a quarta nota4

# %%
soma = (int(n1)+ int(n2) + int(n3)+ int(n4))
print( "a sua média é", soma /4)
# Out:
# a sua média é 2.5

# %%
metros = int(input("informe um valor em metros"))
print("o valor em centimetros é", metros * 100, "cm quadrados")
# Out:
# informe um valor em metros200
# o valor em centimetros é 20000 cm quadrados

# %%
r = int(input("informe o raio do círculo"))
pi = 3.14
print (" a area do círculo é",r**2*pi, "cm quadrados" )
# Out:
# informe o raio do círculo5
#  a area do círculo é 78.5 cm quadrados

# %%
a = int(input("informe a area do quadrado"))
print( "o dobro da area é", a*2)
# Out:
# informe a area do quadrado5
# o dobro da area é 10

# %%
h = int(input("informe quanto você ganha por hora"))
t = int(input("informe quantas horas você trabalha por mês"))
print("seu salario por mês é", h*t)
# Out:
# informe quanto você ganha por hora10
# informe quantas horas você trabalha por mês8
# seu salario por mês é 80

# %%
F = float(input("informe a temperatura em fahrenheit"))
# Out:
# informe a temperatura em fahrenheit130

# %%
5 * ((F - 32)/9)
# Out:
# 54.44444444444444

# %%
C = float(input("informe a temperatura em celsius"))
# Out:
# informe a temperatura em celsius20

# %%
F = ( C * 9/5) + 32

# %%
N1 = int(input("informe um numero inteiro"))
N2 = int(input("informe um outro numero inteiro"))
N3 = float(input("informe um numero real"))
# Out:
# informe um numero inteiro23
# informe um outro numero inteiro34
# informe um numero real46

# %%
(N1*2) * (N2/2)
# Out:
# 782.0

# %%
(N1 * 3) + N3
# Out:
# 115.0

# %%
(N3**3)
# Out:
# 97336.0

# %%
altura = float(input("informe sua altura"))
(72.7*altura) - 58
print (" seu peso ideal é", (72.7*altura - 58))
# Out:
# informe sua altura1.75
#  seu peso ideal é 69.22500000000001
